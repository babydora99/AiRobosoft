# %% [markdown]
# # String :
# A sequence of letters/words in single quote('') or double quote("").

# %% [markdown]
# ### Creating String

# %%
#single word
'Hello'
# Out:
# 'Hello'

# %%
#Entire Phase
"This is a String"
# Out:
# 'This is a String'

# %% [markdown]
# ### Printing a string

# %%
#we can simply declare a String
'Hello World'
# Out:
# 'Hello World'

# %%
#note : we cannot get output of multiple strings in this way
'Hello world 1'
'Hello world 2'
# Out:
# 'Hello world 2'

# %% [markdown]
# we can display the string using 'print' statement.

# %%
#To use print statment from python 3 in python 2(we use future module)
from _-future__ import print_function

print 'hello world'

# %% [markdown]
# ## String Basics
# in Strings , the length of the String can be found out by using function called len()

# %%
len('Hello World')
# Out:
# 11

# %% [markdown]
# ### String indexing
# We can use brackets [] after an object to call it's index.the index starts from 0 in python.

# %%
# assign s as a String
s='Hello World'

#check
s
# Out:
# 'Hello World'

# %%
#print the object
print(s)
# Out:
# Hello World

# %% [markdown]
# let's start indexing

# %%
#show the first element (in this case a letter)
s[0]
# Out:
# 'H'

# %%
s[2]
# Out:
# 'l'

# %% [markdown]
# we can use : to perform slicing in a String

# %%
s[1:]
# Out:
# 'ello World'

# %%
# note: there is no chnage in the original s
s
# Out:
# 'Hello World'

# %%
s[:3]
# Out:
# 'Hel'

# %%
#Everything
s[:]
# Out:
# 'Hello World'

# %%
#last letter 
s[-1]
# Out:
# 'd'

# %%
#grab everything but the last letter
s[:-1]
# Out:
# 'Hello Worl'

# %% [markdown]
# index and slicing is used to grab elements by a specified step size (by default 1)
# Here [start:stop:step size] is taken

# %%
#grab everything . but go in steps size of 1
s[::1]
# Out:
# 'Hello World'

# %%
#grab everything . but go in steps size of 2
s[::2]
# Out:
# 'HloWrd'

# %%
s[::-1] #in reverse order
# Out:
# 'dlroW olleH'

# %% [markdown]
# ### String properties

# %% [markdown]
# Strings are immutable

# %%
s
# Out:
# 'Hello World'

# %%
s[0]='x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 s[0]='x'
#
# TypeError: 'str' object does not support item assignment

# %%
x='Hello guys'

# %%
x
# Out:
# 'Hello guys'

# %%
x=x+", good morning"

# %%
print(x)
# Out:
# Hello guys, good morning

# %% [markdown]
# we can use the multiplication symbol to create repetition

# %%
letter='z'

# %%
letter*10
# Out:
# 'zzzzzzzzzz'

# %% [markdown]
# ## Basic built-in String methods
# Objects have built-in methods which means these methods are functions present inside the object .
# for example : object.method(parameter)

# %%
x
# Out:
# 'Hello guys, good morning'

# %%
#upper-case a String
x.upper()
# Out:
# 'HELLO GUYS, GOOD MORNING'

# %%
#lower-case
x.lower()
# Out:
# 'hello guys, good morning'

# %%
#Split the String by blank space(this is the default)
x.split()
# Out:
# ['Hello', 'guys,', 'good', 'morning']

# %%
#Split by specific element
x.split('o')
# Out:
# ['Hell', ' guys, g', '', 'd m', 'rning']

# %% [markdown]
# ## Print Formatting
# .format() method is used to add formatted object to be printed string statements

# %%
'insert another string with curly brakctes:{}'.format({'The inserted string'})
# Out:
# "insert another string with curly brakctes:{'The inserted string'}"

# %% [markdown]
# ### location aand counting

# %%
print(x)
x.count('o')
# Out:
# Hello guys, good morning
# 4

# %%
s.find('o') # it will tell the position of the word
# Out:
# 4

# %% [markdown]
# the center() method is used to place the string centered between provided string with a certain length

# %%
x.center(60,'s')
# Out:
# 'ssssssssssssssssssHello guys, good morningssssssssssssssssss'

# %% [markdown]
# expandtabs() method is used to expand tab notation \t into spaces

# %%
'hello\thi'.expandtabs()
# Out:
# 'hello   hi'

# %% [markdown]
# ### is check methods

# %%
s='hello'

# %% [markdown]
# isalnum() wii return 'True' if all characters in s are alphanumeric

# %%
s.isalnum()
# Out:
# True

# %% [markdown]
# isalpha() wii return 'True' if all characters in s are alphabetic

# %%
s.isalpha()
# Out:
# True

# %% [markdown]
# islower() will return 'True' if all cased characters in s are lowercase and there is at least one cased character in s,False otheriwise

# %%
s.islower()
# Out:
# True

# %% [markdown]
# isspace() will return 'True' if all characters in s are whitesppace

# %%
s.isspace()
# Out:
# False

# %% [markdown]
# istitle() will return 'True' , if s is a title cased string (for ex: Prince - it's a title bcz it's first letter is in uppercase  )

# %%
s.istitle()
# Out:
# False

# %% [markdown]
# isupper() will return 'True' if all cased characters in s are uppercase

# %%
s.isupper()
# Out:
# False

# %% [markdown]
# Another method is endswith() which is essentially same as boolean check on s[-1]

# %%
s.endswith('o')
# Out:
# True

# %% [markdown]
# ## Built-in Reg. Expressions

# %% [markdown]
# .split() is used to split the string at a certain element and return a list of the result.
# .partition() is used to return a tuple that includes the separator(the first occurance ), the first half and the end half.

# %%
s.split('e')
# Out:
# ['h', 'llo']

# %%
s.partition('e')
# Out:
# ('h', 'e', 'llo')

# %% [markdown]
# ## Lists

# %% [markdown]
# list is ordered and mutable and can hold different object type

# %%
my_list=[1,2,'a String',89]

# %%
my_list
# Out:
# [1, 2, 'a String', 89]

# %% [markdown]
# len() function is used to tell the how many items are in the sequence of the list

# %%
len(my_list)
# Out:
# 4

# %% [markdown]
# ### indexing and slicing

# %%
my_list=[1,2,'three',4,'five']

# %%
#grab element at index 0
my_list[0]
# Out:
# 1

# %%
#grab index 1 and everything past it
my_list[1:]
# Out:
# [2, 'three', 4, 'five']

# %%
#grab everything upto index 3
my_list[:3]
# Out:
# [1, 2, 'three']

# %% [markdown]
# we can use '+' concatenation in lists

# %%
my_list+['new item']
# Out:
# [1, 2, 'three', 4, 'five', 'new item']

# %% [markdown]
# note : this will not change the original list

# %%
my_list
# Out:
# [1, 2, 'three', 4, 'five']

# %% [markdown]
# in this case,you can reassign the list to make the permanent change

# %%
#reassign
my_list=my_list+["concatenation permanently"]

# %%
my_list
# Out:
# [1, 2, 'three', 4, 'five', 'concatenation permanently']

# %%
#make the list double
my_list*2
# Out:
# [1,
#  2,
#  'three',
#  4,
#  'five',
#  'concatenation permanently',
#  1,
#  2,
#  'three',
#  4,
#  'five',
#  'concatenation permanently']

# %% [markdown]
# ## Basic list methods

# %%
#creating a new list
l=[1,2,3]

# %%
l.append("anything")

# %%
l
# Out:
# [1, 2, 3, 'anything']

# %%
l.pop(0) #pop off the value in the specified index
# Out:
# 1

# %%
l
# Out:
# [2, 3, 'anything']

# %%
l.pop() #by default it will pop the last element
# Out:
# 3

# %%
l
# Out:
# [2, 3]

# %% [markdown]
# we can use the **sort** and **reverse** method to also effect our list

# %%
new_list=['a','e','x','b','c']
new_list
# Out:
# ['a', 'e', 'x', 'b', 'c']

# %%
new_list.reverse()

# %%
new_list
# Out:
# ['c', 'b', 'x', 'e', 'a']

# %%
#sort method will sort the entire list in ascending order
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %% [markdown]
# ### Nested Lists
# List inside a list is called Nested List

# %%
l1=[1,2,3]
l2=[3,4,5]
l3=[2,4,6]

# %%
matrix=[l1,l2,l3]

# %%
matrix
# Out:
# [[1, 2, 3], [3, 4, 5], [2, 4, 6]]

# %%
#grab first item in matri object
matrix[0]
# Out:
# [1, 2, 3]

# %%
#grab the first item of the first item in the matrix object
matrix[0][0]
# Out:
# 1

# %% [markdown]
# ## List Comprehensions

# %%
#Build a list comprehension by deconstructing a for loop within a []
first_col=[row[0] for row in matrix]
first_col
# Out:
# [1, 3, 2]

# %% [markdown]
# ## Advanced Lists

# %%
l=[1,2,3]

# %% [markdown]
# #### append

# %%
l.append(4)

# %%
l
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# #### count

# %%
l.count(10)
# Out:
# 0

# %%
l.count(2)
# Out:
# 1

# %% [markdown]
# #### extend
# diference between append and extend

# %% [markdown]
# append : Appends object at end

# %%
x=[1,2,3]
x.append([4,5])

# %%
x
# Out:
# [1, 2, 3, [4, 5]]

# %% [markdown]
# extend : extends list by appending elements from the iterable

# %%
x=[1,2,3]
x.extend([4,5])
print(x)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# #### index

# %%
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l.index(2) # it will give the index of the element '2'
# Out:
# 1

# %% [markdown]
# #### insert
# Syntax : insert(index,object)

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
#place a letter at the index 2
l.insert(2,'inserted')
l
# Out:
# [1, 2, 'inserted', 3, 4]

# %% [markdown]
# #### pop

# %%
ele=l.pop()

# %%
l
# Out:
# [1, 2, 'inserted', 3]

# %% [markdown]
# #### remove
# it removes the first occurance of a value

# %%
l
# Out:
# [1, 2, 'inserted', 3]

# %%
l.remove('inserted')

# %%
l
# Out:
# [1, 2, 3]

# %%
x=[1,2,3,4,3]
x.remove(3)
print(x)
# Out:
# [1, 2, 4, 3]

# %% [markdown]
# #### reverse
# it helps to reverse a list. Note : this occurs in place , effects the list permanently

# %%
x.reverse()
x
# Out:
# [3, 4, 2, 1]

# %% [markdown]
# #### sort
# sort will Sort the list in place

# %%
l
# Out:
# [3, 2, 1]

# %%
l.sort()

# %%
l
# Out:
# [1, 2, 3]
